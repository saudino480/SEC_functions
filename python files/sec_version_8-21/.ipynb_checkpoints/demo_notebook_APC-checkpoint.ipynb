# %%
#SWN20140227 Table: 0
#remaining bug: bcf in the first column...

# %%
# %load_ext autoreload
# %autoreload 2
import pickle
import re
import pandas as pd
import numpy as np
from IPython.display import display, HTML
from zlu_functions import del_subset_col, set_col_headers, \
                          row_header_to_col,remove_rows_for_total_value, \
                          dfs_need_transpose, remove_cols_for_fair_value, \
                          collar_fill_empty,remove_empty_rows_and_cols, \
                          df_column_uniquify, verticalSplit_instrument, \
                          verticalSplit_ZLU
from nel_functions import delete_uninformative,delete_empty,delete_duplicated, \
                          delete_subset,get_vertically_stacked_subtables, \
                          vertically_stacked_subtable_cleaner
from helper import volumeCleaner, dateCleaner, priceCleaner,trimDictonary, \
                   instrumentCleaner, productCleaner, filterBusiness,columnSorter, \
                   verticalSplit, anyCleaner
#pickle_in=open('../SEC_Data/Hedge/hedge_dfs_all_new.pickle','rb')

pickle_in=open('hedge_dfs_subset_8_18.pickle', 'rb')
df_dic=pickle.load(pickle_in)

delete_empty(df_dic)
df_dic = trimDictonary(df_dic,[])#remove empty list of dfs
del_dfs_dic_0 = delete_duplicated(df_dic) #remove duplicated dfs within a list; again
del_dfs_dic_1 = delete_subset(df_dic)

ticker_list = []

for k in df_dic.keys():
    if k[:3] not in ticker_list:
        print(k[:3])
        ticker_list.append(k[:3])


df_dic = filterBusiness(df_dic, 'APC')
# df_dic={'CLR20100226':df_dic['CLR20100226']}
#del df_dic['PKD20090302'] #false positive
with open('output_before_spliting.csv','w') as f:
    pass
#preprocessing for all dfs
for k in df_dic.keys():
    for i in range(len(df_dic[k])):

        df=df_dic[k][i]
        df=set_col_headers(df) #set headers
        df=del_subset_col(df) #delete redundant cols
        df=remove_rows_for_total_value(df) #if any row for total value; save it
        df=remove_cols_for_fair_value(df)
        df_dic[k][i]=df
        with open('output_before_spliting.csv','a') as f:
            df=df_dic[k][i]
            f.writelines(k+'\n'+'table:'+str(i))
            try: df.to_csv(f,encoding='cp1252')
            except: df.to_csv(f,encoding='utf-8')

#         print(k,'Original Table:',i,'-'*10)
#         display(HTML(df.to_html()))

#Vertical Split
# for k in df_dic.keys(): #apply Sam's spliting function
    #print(k)
#     if 'RRC' in k: df_dic[k] = verticalSplit(df_dic[k])
#     elif k=='BRY20110301':
#         split_dfs = []
#         for table in df_dic[k]:
#             df1 = table.iloc[:, 0:3]
#             df2 = table.iloc[:, 3:]
#             split_dfs.append(df1)
#             split_dfs.append(df2)
#             df_dic[k]=split_dfs
#     else: df_dic[k] = verticalSplit(df_dic[k])
#     df_dic[k]=verticalSplit_instrument(df_dic[k])
#     if 'RRC' in k: df_dic[k] = verticalSplit(df_dic[k])
#     else: df_dic[k] = verticalSplit_ZLU(df_dic[k])
 

for k in df_dic.keys():
    #print(k)
    for i in range(len(df_dic[k])):
        df=df_dic[k][i]
        if df.shape[1]==1: df=pd.DataFrame()
        elif isinstance(df, pd.DataFrame): #after new headers; ignore empty dfs
            df=del_subset_col(df) #delete redundant cols
            df=remove_rows_for_total_value(df) #if any row for total value; save it
            df=remove_cols_for_fair_value(df)
            df=row_header_to_col(df)
            df=dfs_need_transpose(df)
            df=collar_fill_empty(df)
            df=df_column_uniquify(df)
            df_dic[k][i]=remove_empty_rows_and_cols(df)
#             print(k,'Table:',i,'-'*10,'After preprocessing')
#             display(HTML(df.to_html()))


split_dictonary1 = {'oil_split' : ['oil'],
                    'gas_split' : ['gas'],
                    'ngl_split' : ['ngl']}

split_dictonary2 = {}

#Vertical Split
for k in df_dic.keys(): #apply Sam's spliting function
    print(k)
    df_dic[k] = verticalSplit(df_dic[k], dictonary = split_dictonary1, verbose = True)
#     df_dic[k] = verticalSplit(df_dic[k], dictonary = split_dictonary2, verbose = True)
    df_dic[k] = verticalSplit_instrument(df_dic[k], kw1 = 'two way collar', kw2 = 'three way collar')
    df_dic[k] = verticalSplit_instrument(df_dic[k], kw1 = 'two way collar', kw2 = 'fixed price')
    df_dic[k] = verticalSplit_instrument(df_dic[k], kw1 = 'fixed price', kw2 = 'three way collar')
    df_dic[k] = verticalSplit_instrument(df_dic[k], kw1 = 'basis swap', kw2 = 'three way collar')
    df_dic[k] = verticalSplit_instrument(df_dic[k], kw1 = 'basis swap', kw2 = 'fixed price')

    for i in range(len(df_dic[k])):
        df=df_dic[k][i]
        if df.shape[1]==1: df=pd.DataFrame()
        elif isinstance(df, pd.DataFrame): #after new headers; ignore empty dfs
            df=del_subset_col(df) #delete redundant cols
            df=remove_rows_for_total_value(df) #if any row for total value; save it
            df=remove_cols_for_fair_value(df)
            df=df_column_uniquify(df)
            df_dic[k][i]=remove_empty_rows_and_cols(df)
           
#Horizontally Split
del_dfs_dic3=get_vertically_stacked_subtables(df_dic)
vertically_stacked_subtable_cleaner(df_dic,del_dfs_dic3,exclusion=True, excluded_ticker=('MXC', 'OXY', 'HOC'))

delete_empty(df_dic)
df_dic = trimDictonary(df_dic,[])#remove empty list of dfs
del_dfs_dic_2 = delete_duplicated(df_dic) #remove duplicated dfs within a list; again
del_dfs_dic_3 = delete_subset(df_dic)

for k in df_dic.keys(): #apply Sam's spliting function
    for i in range(len(df_dic[k])):
        df=df_dic[k][i]
        if df.shape[1]==1: df=pd.DataFrame()
        elif isinstance(df, pd.DataFrame): #after new headers; ignore empty dfs
            df=del_subset_col(df) #delete redundant cols
            df_dic[k][i]=df_column_uniquify(df)
            df_dic[k][i]=remove_empty_rows_and_cols(df)
            
with open('output_before_sam.csv','w') as f:
    pass
with open('output_after_sam.csv','w') as f:
    pass
for k in df_dic.keys():
    for i in range(len(df_dic[k])):
        with open('output_before_sam.csv','a') as f:
            df=df_dic[k][i]
            f.writelines(k+'\n'+'table:'+str(i))
            try: df.to_csv(f,encoding='cp1252')
            except: df.to_csv(f,encoding='utf-8')

date_keys = []               
date_stop = []

price_keys = ['weighted average floor price per mcf','weighted average price per mcf',
              'weighted average price per bbl', 'weighted average floor price per bbl',
              'weighted,average,price to be,swapped,($/mmbtu),,', 'weighted,average,floor,price,($/mmbtu),,',
              'weighted,average,ceiling,price,($/mmbtu),,', 'weighted,average,basis,differential,($/mmbtu),,',
              'weighted average price per mmbtu', 'weighted average price', 'weighted average floor price',
              'weighted average ceiling price', 'weighted average basis differential','swapsweightedaverage',
              'price per barrel',
              'call','floor','ceiling', 'price per mmbtu', 'fixed price,range', 'fixed price', 
              'ceiling sold', 'floor sold', 'ceiling purchased', 'floor purchased']

price_stop = ['fixed price swaps,,,mbbls,', 'call options,,,mbbls,', 
              ',fixed price swaps,production period,,', 'mmbtu/d', 'bbls/d']

volume_keys = ['mmbtu/bbl/gj','mmbtu/bbl','MMBtu,(in 000 s)','GJ,(in 000 s)', 'mbbls/d',
               'mmbtu/d', 'total volumes']
volume_keys = [x.lower() for x in volume_keys]

volume_stop = []               
volume_helper = ['btu', 'bbl', 'gj']

#set verbose to True to turn on the diagonstic output for Sam's functions
verbose = False
key_override = True
                
for k in df_dic.keys():
    print(k)
    for i in range(len(df_dic[k])):
        df=df_dic[k][i]
#         display(HTML(df.to_html()))
        if df.shape[0]>0: #apply Sam's functions to non-empty dfs
            print(k,'Table:',i,'-'*10,'Before Sam function')
            col_lst=[re.sub("[,]+","",col) if 'product_type' in col or 'instrument_type' in col else col for col in df.columns]
            df.columns=col_lst
            display(HTML(df.to_html()))
            df = instrumentCleaner(df, key_words = "", stop_words = "", verbose = verbose)
            df = productCleaner(df, key_words = "", stop_words = "", verbose = verbose)
            df = priceCleaner(df, key_words = price_keys, stop_words = price_stop,\
                                  verbose = verbose, key_override = key_override)
#             df = anyCleaner(df, key_words = volume_keys, stop_words = volume_stop, \
#                             units_column_helper = volume_helper, \
#                             key_override = key_override, condense = True, cleaner_label = 'vol')
#             display(HTML(df.to_html()))
            df = volumeCleaner(df, key_words = volume_keys, stop_words = volume_stop,\
                                   verbose = verbose, key_override = key_override)
            df = dateCleaner(df, value_ids = ["20\d{2}"], impute = True)
            #ZLU's change begins
            display(HTML(df.to_html()))
            col_lst=[col for col in df.columns if 'vol' in col]
            for col in col_lst:
                df.loc[:,col]=df.loc[:,col].str.replace('[,\(\)]',"")
    #         display(HTML(df.to_html()))
    
    # build into functions volumeCleaner, row delete can stay here
#             if 'vol_2_type' in df.columns:
#                 for row_idx in range(df.shape[0]):
#                     if df.iloc[row_idx,df.columns=='vol_1'].values=="": 
#                         df.iloc[row_idx,df.columns=='vol_1'] = df.iloc[row_idx,df.columns=='vol_2'].values
#                         df.iloc[row_idx,df.columns=='vol_1_type']=df.iloc[row_idx,df.columns=='vol_2_type'].values
#                         df.iloc[row_idx,df.columns=='vol_2'] = ""
            col_lst=['vol' in col for col in df.columns]
            row_lst=list(range(df.shape[0]))
            for row_idx in range(df.shape[0]):
                if not any(df.iloc[row_idx,col_lst].str.contains('\d')):
                    row_lst.remove(row_idx)
            df=df.iloc[row_lst]
#             if all(df.loc[:,'vol_1_type']=='volume'): df.loc[:,'vol_1_type']=df.loc[:,'product_type'].str.extract('\(([^\)]+)\)')
#                         #ZLU's change ends
            print(k+' ,table:'+str(i)+'-----After Sam functions----')
            display(HTML(df.to_html()))
            print('~'*50)
        else: df=pd.DataFrame()
        df_dic[k][i]=df

del_dfs_dic_5 = delete_uninformative(df_dic)
print('1',len(df_dic))
delete_empty(df_dic)
print('2',len(df_dic))
df_dic = trimDictonary(df_dic,[])#remove empty list of dfs
print('3',len(df_dic))
del_dfs_dic_2 = delete_duplicated(df_dic) #remove duplicated dfs within a list; again
print('4',len(df_dic))
del_dfs_dic_3 = delete_subset(df_dic)
print('5',len(df_dic))

print(len(df_dic.keys()))

big_df = pd.DataFrame()

for k in df_dic.keys():
    doc_id = k
    processed_dfs = df_dic[k]
    for df in processed_dfs:
        unprocessed_cols = columnSorter(df)
        print(unprocessed_cols)
        df.drop(unprocessed_cols, axis = 1, inplace = True)
             #zlu change starts
        col_lst=['price' in col for col in df.columns]
        row_lst=list(range(df.shape[0]))
        df['red_flag']=''
        for row_idx in range(df.shape[0]):
            if not any(df.iloc[row_idx,col_lst].str.contains('\d')):
                df.iloc[row_idx,-1]=1
        #zlu change ends

#         display(HTML(df.to_html()))
        length = df.shape[0]
        doc_id_col = np.array([doc_id]*length)
        df.insert(0, 'doc_id', doc_id_col)
        big_df = pd.concat([big_df, df], axis = 0, join = 'outer', sort = False)

print(big_df.shape)

if any(big_df['red_flag'] != ''):
    print("Check the red_flag column for missing values at")
    #print('\n\n', big_df.iloc[big_df['red_flag'] != '', ].index)

try: big_df.to_csv('APC_clean.csv', encoding='cp1252')
except: big_df.to_csv('APC_clean.csv', encoding = 'utf-8')
# for k in df_dic.keys():
#     for i in range(len(df_dic[k])):
#         with open('APA_clean.csv','a') as f:
#             df=df_dic[k][i]
#             f.writelines(k+'\n'+'table:'+str(i))
#             try: df.to_csv(f,encoding='cp1252')
#             except: df.to_csv(f,encoding='utf-8')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# AHC
# APA
# APC
# ARE
# CHK
# CLR
# COG
# COP
# CPE
# CRC
# CRK
# CRZ
# CXO
# DNR
# DVN
# ECA
# EOG
# GPO
# HES
# LPI
# MRO
# MTD
# MUR
# NBL
# NOG
# OAS
# OXY
# PDC
# PE2
# PET
# PXD
# QEP
# RRC
# SM2
# SWN
# UNT
# WLL
# WPX
# WTI
# XEC
# APC20040304
# There was nothing to split!
# There was nothing to split!
# APC20050315
# There was nothing to split!
# There was nothing to split!
# APC20060303
# There was nothing to split!
# There was nothing to split!
# APC20070228
# Splitting on  oil_split
# Split  0 columns:
#  [',product_type,additional', 'three way collars (mbbls/d),crude oil,price per mmbtu', 'ceiling sold price,crude oil,price per barrel', 'floor purchased price,crude oil,price per barrel', 'floor sold price,crude oil,price per barrel', 'two way collars (mbbls/d),crude oil,price per barrel', 'ceiling sold price,crude oil,price per barrel,', 'floor purchased price,crude oil,price per barrel,', 'fixed price (mbbls/d),crude oil,price per barrel', 'price per barrel,crude oil,price per barrel']
# Split  0 pure columns:
#  ['three way collars (mbbls/d),crude oil,price per mmbtu', 'ceiling sold price,crude oil,price per barrel', 'floor purchased price,crude oil,price per barrel', 'floor sold price,crude oil,price per barrel', 'two way collars (mbbls/d),crude oil,price per barrel', 'ceiling sold price,crude oil,price per barrel,', 'floor purchased price,crude oil,price per barrel,', 'fixed price (mbbls/d),crude oil,price per barrel', 'price per barrel,crude oil,price per barrel']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (mbbls/d),crude oil,price per mmbtu</th>
#       <th>ceiling sold price,crude oil,price per barrel</th>
#       <th>floor purchased price,crude oil,price per barrel</th>
#       <th>floor sold price,crude oil,price per barrel</th>
#       <th>two way collars (mbbls/d),crude oil,price per barrel</th>
#       <th>ceiling sold price,crude oil,price per barrel,</th>
#       <th>floor purchased price,crude oil,price per barrel,</th>
#       <th>fixed price (mbbls/d),crude oil,price per barrel</th>
#       <th>price per barrel,crude oil,price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2007</td>
#       <td>35</td>
#       <td>$86.16</td>
#       <td>$58.57</td>
#       <td>$43.57</td>
#       <td>19</td>
#       <td>$60.40</td>
#       <td>$44.33</td>
#       <td>27</td>
#       <td>$51.44</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2008</td>
#       <td>86</td>
#       <td>$92.98</td>
#       <td>$56.07</td>
#       <td>$41.07</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2009</td>
#       <td>48</td>
#       <td>$87.04</td>
#       <td>$52.51</td>
#       <td>$37.51</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Average2010|2012</td>
#       <td>8</td>
#       <td>$87.04</td>
#       <td>$49.35</td>
#       <td>$34.34</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (mbbls/d),crude oil,price per mmbtu</th>
#       <th>ceiling sold price,crude oil,price per barrel</th>
#       <th>floor purchased price,crude oil,price per barrel</th>
#       <th>floor sold price,crude oil,price per barrel</th>
#       <th>two way collars (mbbls/d),crude oil,price per barrel</th>
#       <th>ceiling sold price,crude oil,price per barrel,</th>
#       <th>floor purchased price,crude oil,price per barrel,</th>
#       <th>fixed price (mbbls/d),crude oil,price per barrel</th>
#       <th>price per barrel,crude oil,price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2007</td>
#       <td>35</td>
#       <td>$86.16</td>
#       <td>$58.57</td>
#       <td>$43.57</td>
#       <td>19</td>
#       <td>$60.40</td>
#       <td>$44.33</td>
#       <td>27</td>
#       <td>$51.44</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2008</td>
#       <td>86</td>
#       <td>$92.98</td>
#       <td>$56.07</td>
#       <td>$41.07</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2009</td>
#       <td>48</td>
#       <td>$87.04</td>
#       <td>$52.51</td>
#       <td>$37.51</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Average2010|2012</td>
#       <td>8</td>
#       <td>$87.04</td>
#       <td>$49.35</td>
#       <td>$34.34</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  gas_split
# Split  1 columns:
#  [',product_type,additional', 'three way collars (thousand mmbtu/d),natural gas,', 'ceiling sold price,natural gas,price per mmbtu', 'floor purchased price,natural gas,price per mmbtu', 'floor sold price,natural gas,price per mmbtu', 'two way collars (thousand mmbtu/d),natural gas,price per mmbtu', 'ceiling sold price,natural gas,price per mmbtu,', 'floor purchase price,natural gas,price per mmbtu', 'fixed price (thousand mmbtu/d),natural gas,price per mmbtu', 'price per mmbtu,natural gas,price per mmbtu', 'basis swaps (thousand mmbtu/d),natural gas,price per mmbtu', 'price per mmbtu,natural gas,price per mmbtu,']
# Split  1 pure columns:
#  ['three way collars (thousand mmbtu/d),natural gas,', 'ceiling sold price,natural gas,price per mmbtu', 'floor purchased price,natural gas,price per mmbtu', 'floor sold price,natural gas,price per mmbtu', 'two way collars (thousand mmbtu/d),natural gas,price per mmbtu', 'ceiling sold price,natural gas,price per mmbtu,', 'floor purchase price,natural gas,price per mmbtu', 'fixed price (thousand mmbtu/d),natural gas,price per mmbtu', 'price per mmbtu,natural gas,price per mmbtu', 'basis swaps (thousand mmbtu/d),natural gas,price per mmbtu', 'price per mmbtu,natural gas,price per mmbtu,']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,</th>
#       <th>ceiling sold price,natural gas,price per mmbtu</th>
#       <th>floor purchased price,natural gas,price per mmbtu</th>
#       <th>floor sold price,natural gas,price per mmbtu</th>
#       <th>two way collars (thousand mmbtu/d),natural gas,price per mmbtu</th>
#       <th>ceiling sold price,natural gas,price per mmbtu,</th>
#       <th>floor purchase price,natural gas,price per mmbtu</th>
#       <th>fixed price (thousand mmbtu/d),natural gas,price per mmbtu</th>
#       <th>price per mmbtu,natural gas,price per mmbtu</th>
#       <th>basis swaps (thousand mmbtu/d),natural gas,price per mmbtu</th>
#       <th>price per mmbtu,natural gas,price per mmbtu,</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2007</td>
#       <td>30</td>
#       <td>$11.23</td>
#       <td>$9.00</td>
#       <td>$6.00</td>
#       <td>386</td>
#       <td>$10.73</td>
#       <td>$6.27</td>
#       <td>405</td>
#       <td>$7.14</td>
#       <td>557</td>
#       <td>$(1.08</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2008</td>
#       <td>500</td>
#       <td>$14.26</td>
#       <td>$7.50</td>
#       <td>$5.00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>105</td>
#       <td>$8.16</td>
#       <td>575</td>
#       <td>$(1.05</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2009</td>
#       <td>50</td>
#       <td>$12.60</td>
#       <td>$7.50</td>
#       <td>$5.00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>90</td>
#       <td>$7.84</td>
#       <td>20</td>
#       <td>$(1.08</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Average2010|2012</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,</th>
#       <th>ceiling sold price,natural gas,price per mmbtu</th>
#       <th>floor purchased price,natural gas,price per mmbtu</th>
#       <th>floor sold price,natural gas,price per mmbtu</th>
#       <th>two way collars (thousand mmbtu/d),natural gas,price per mmbtu</th>
#       <th>ceiling sold price,natural gas,price per mmbtu,</th>
#       <th>floor purchase price,natural gas,price per mmbtu</th>
#       <th>fixed price (thousand mmbtu/d),natural gas,price per mmbtu</th>
#       <th>price per mmbtu,natural gas,price per mmbtu</th>
#       <th>basis swaps (thousand mmbtu/d),natural gas,price per mmbtu</th>
#       <th>price per mmbtu,natural gas,price per mmbtu,</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2007</td>
#       <td>30</td>
#       <td>$11.23</td>
#       <td>$9.00</td>
#       <td>$6.00</td>
#       <td>386</td>
#       <td>$10.73</td>
#       <td>$6.27</td>
#       <td>405</td>
#       <td>$7.14</td>
#       <td>557</td>
#       <td>$(1.08</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2008</td>
#       <td>500</td>
#       <td>$14.26</td>
#       <td>$7.50</td>
#       <td>$5.00</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>105</td>
#       <td>$8.16</td>
#       <td>575</td>
#       <td>$(1.05</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2009</td>
#       <td>50</td>
#       <td>$12.60</td>
#       <td>$7.50</td>
#       <td>$5.00</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>90</td>
#       <td>$7.84</td>
#       <td>20</td>
#       <td>$(1.08</td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  ngl_split
# Split  2 columns:
#  [',product_type,additional']
# Split  2 pure columns:
#  []
# APC20080229
# There was nothing to split!
# There was nothing to split!
# APC20090225
# There was nothing to split!
# There was nothing to split!
# APC20100223
# There was nothing to split!
# There was nothing to split!
# APC20110223
# There was nothing to split!
# There was nothing to split!
# APC20120221
# Splitting on  oil_split
# Split  0 columns:
#  [',product_type,additional', 'three way collars (mbbls/d),crude oil,average price per mmbtu', 'ceiling sold price (call),crude oil,average price per barrel', 'floor purchased price (put),crude oil,average price per barrel', 'floor sold price (put),crude oil,average price per barrel']
# Split  0 pure columns:
#  ['three way collars (mbbls/d),crude oil,average price per mmbtu', 'ceiling sold price (call),crude oil,average price per barrel', 'floor purchased price (put),crude oil,average price per barrel', 'floor sold price (put),crude oil,average price per barrel']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (mbbls/d),crude oil,average price per mmbtu</th>
#       <th>ceiling sold price (call),crude oil,average price per barrel</th>
#       <th>floor purchased price (put),crude oil,average price per barrel</th>
#       <th>floor sold price (put),crude oil,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2012</td>
#       <td>2</td>
#       <td>$92.50</td>
#       <td>$50.00</td>
#       <td>$35.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (mbbls/d),crude oil,average price per mmbtu</th>
#       <th>ceiling sold price (call),crude oil,average price per barrel</th>
#       <th>floor purchased price (put),crude oil,average price per barrel</th>
#       <th>floor sold price (put),crude oil,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2012</td>
#       <td>2</td>
#       <td>$92.50</td>
#       <td>$50.00</td>
#       <td>$35.00</td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  gas_split
# Split  1 columns:
#  [',product_type,additional', 'three way collars (thousand mmbtu/d),natural gas,', 'ceiling sold price (call),natural gas,average price per mmbtu', 'floor purchased price (put),natural gas,average price per mmbtu', 'floor sold price (put),natural gas,average price per mmbtu', 'fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu', 'average price per mmbtu,natural gas,average price per mmbtu']
# Split  1 pure columns:
#  ['three way collars (thousand mmbtu/d),natural gas,', 'ceiling sold price (call),natural gas,average price per mmbtu', 'floor purchased price (put),natural gas,average price per mmbtu', 'floor sold price (put),natural gas,average price per mmbtu', 'fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu', 'average price per mmbtu,natural gas,average price per mmbtu']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,</th>
#       <th>ceiling sold price (call),natural gas,average price per mmbtu</th>
#       <th>floor purchased price (put),natural gas,average price per mmbtu</th>
#       <th>floor sold price (put),natural gas,average price per mmbtu</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu</th>
#       <th>average price per mmbtu,natural gas,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2012</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1000</td>
#       <td>$4.69</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>Neg1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013</td>
#       <td>450</td>
#       <td>$6.57</td>
#       <td>$5.00</td>
#       <td>$4.00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,</th>
#       <th>ceiling sold price (call),natural gas,average price per mmbtu</th>
#       <th>floor purchased price (put),natural gas,average price per mmbtu</th>
#       <th>floor sold price (put),natural gas,average price per mmbtu</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu</th>
#       <th>average price per mmbtu,natural gas,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2012</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>1000</td>
#       <td>$4.69</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>Neg1</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2013</td>
#       <td>450</td>
#       <td>$6.57</td>
#       <td>$5.00</td>
#       <td>$4.00</td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  ngl_split
# Split  2 columns:
#  [',product_type,additional']
# Split  2 pure columns:
#  []
# APC20130219
# Splitting on  oil_split
# Split  0 columns:
#  [',product_type,additional', 'three way collars (mbbls/d),crude oil,', 'ceiling sold price (call),crude oil,average price per barrel', 'floor purchased price (put),crude oil,average price per barrel', 'floor sold price (put),crude oil,average price per barrel', 'fixed price contracts (mbbls/d),crude oil,average price per barrel', 'average price per barrel,crude oil,average price per barrel']
# Split  0 pure columns:
#  ['three way collars (mbbls/d),crude oil,', 'ceiling sold price (call),crude oil,average price per barrel', 'floor purchased price (put),crude oil,average price per barrel', 'floor sold price (put),crude oil,average price per barrel', 'fixed price contracts (mbbls/d),crude oil,average price per barrel', 'average price per barrel,crude oil,average price per barrel']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (mbbls/d),crude oil,</th>
#       <th>ceiling sold price (call),crude oil,average price per barrel</th>
#       <th>floor purchased price (put),crude oil,average price per barrel</th>
#       <th>floor sold price (put),crude oil,average price per barrel</th>
#       <th>fixed price contracts (mbbls/d),crude oil,average price per barrel</th>
#       <th>average price per barrel,crude oil,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2013 Settlement</td>
#       <td>26</td>
#       <td>$125.15</td>
#       <td>$105.00</td>
#       <td>$85.00</td>
#       <td>40</td>
#       <td>$107.04</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (mbbls/d),crude oil,</th>
#       <th>ceiling sold price (call),crude oil,average price per barrel</th>
#       <th>floor purchased price (put),crude oil,average price per barrel</th>
#       <th>floor sold price (put),crude oil,average price per barrel</th>
#       <th>fixed price contracts (mbbls/d),crude oil,average price per barrel</th>
#       <th>average price per barrel,crude oil,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2013 Settlement</td>
#       <td>26</td>
#       <td>$125.15</td>
#       <td>$105.00</td>
#       <td>$85.00</td>
#       <td>40</td>
#       <td>$107.04</td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  gas_split
# Split  1 columns:
#  [',product_type,additional', 'three way collars (thousand mmbtu/d),natural gas,', 'fixed price contracts (thousand mmbtu/d),natural gas,', 'average price per mmbtu,natural gas,']
# Split  1 pure columns:
#  ['three way collars (thousand mmbtu/d),natural gas,', 'fixed price contracts (thousand mmbtu/d),natural gas,', 'average price per mmbtu,natural gas,']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,</th>
#       <th>average price per mmbtu,natural gas,</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2013 Settlement</td>
#       <td>NaN</td>
#       <td>1185</td>
#       <td>$4.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>Neg1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,product_type,additional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,</th>
#       <th>average price per mmbtu,natural gas,</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2013 Settlement</td>
#       <td></td>
#       <td>1185</td>
#       <td>$4.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>Neg1</td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  ngl_split
# Split  2 columns:
#  [',product_type,additional']
# Split  2 pure columns:
#  []
# APC20140228
# Splitting on  oil_split
# Split  0 columns:
#  [',,product_type,additional', 'fixed price contracts (mbbls/d),crude oil,average price per mmbtu', 'average price per barrel,crude oil,average price per mmbtu']
# Split  0 pure columns:
#  ['fixed price contracts (mbbls/d),crude oil,average price per mmbtu', 'average price per barrel,crude oil,average price per mmbtu']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>fixed price contracts (mbbls/d),crude oil,average price per mmbtu</th>
#       <th>average price per barrel,crude oil,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2014 Settlement</td>
#       <td>107</td>
#       <td>$100.58</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>,2015 Settlement</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>fixed price contracts (mbbls/d),crude oil,average price per mmbtu</th>
#       <th>average price per barrel,crude oil,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2014 Settlement</td>
#       <td>107</td>
#       <td>$100.58</td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  gas_split
# Split  1 columns:
#  [',,product_type,additional', 'three way collars (thousand mmbtu/d),natural gas,', 'ceiling sold price (call),natural gas,average price per mmbtu', 'floor purchased price (put),natural gas,average price per mmbtu', 'floor sold price (put),natural gas,average price per mmbtu', 'fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu', 'average price per mmbtu,natural gas,average price per mmbtu', 'extendable fixed price contracts (thousand mmbtu/d) ,,natural gas,average price per mmbtu', 'average price per mmbtu,natural gas,average price per mmbtu,']
# Split  1 pure columns:
#  ['three way collars (thousand mmbtu/d),natural gas,', 'ceiling sold price (call),natural gas,average price per mmbtu', 'floor purchased price (put),natural gas,average price per mmbtu', 'floor sold price (put),natural gas,average price per mmbtu', 'fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu', 'average price per mmbtu,natural gas,average price per mmbtu', 'extendable fixed price contracts (thousand mmbtu/d) ,,natural gas,average price per mmbtu', 'average price per mmbtu,natural gas,average price per mmbtu,']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,</th>
#       <th>ceiling sold price (call),natural gas,average price per mmbtu</th>
#       <th>floor purchased price (put),natural gas,average price per mmbtu</th>
#       <th>floor sold price (put),natural gas,average price per mmbtu</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu</th>
#       <th>average price per mmbtu,natural gas,average price per mmbtu</th>
#       <th>extendable fixed price contracts (thousand mmbtu/d) ,,natural gas,average price per mmbtu</th>
#       <th>average price per mmbtu,natural gas,average price per mmbtu,</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2014 Settlement</td>
#       <td>600</td>
#       <td>$5.01</td>
#       <td>$3.75</td>
#       <td>$2.75</td>
#       <td>600</td>
#       <td>$4.26</td>
#       <td>400</td>
#       <td>$4.19</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>,2015 Settlement</td>
#       <td>635</td>
#       <td>$4.76</td>
#       <td>$3.75</td>
#       <td>$2.75</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,</th>
#       <th>ceiling sold price (call),natural gas,average price per mmbtu</th>
#       <th>floor purchased price (put),natural gas,average price per mmbtu</th>
#       <th>floor sold price (put),natural gas,average price per mmbtu</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu</th>
#       <th>average price per mmbtu,natural gas,average price per mmbtu</th>
#       <th>extendable fixed price contracts (thousand mmbtu/d) ,,natural gas,average price per mmbtu</th>
#       <th>average price per mmbtu,natural gas,average price per mmbtu,</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2014 Settlement</td>
#       <td>600</td>
#       <td>$5.01</td>
#       <td>$3.75</td>
#       <td>$2.75</td>
#       <td>600</td>
#       <td>$4.26</td>
#       <td>400</td>
#       <td>$4.19</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>,2015 Settlement</td>
#       <td>635</td>
#       <td>$4.76</td>
#       <td>$3.75</td>
#       <td>$2.75</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  ngl_split
# Split  2 columns:
#  [',,product_type,additional']
# Split  2 pure columns:
#  []
# APC20150220
# There was nothing to split!
# APC20160217
# Splitting on  oil_split
# Split  0 columns:
#  [',,product_type,additional', 'three way collars (mbbls/d),oil,', 'ceiling sold price (call),oil,average price per barrel', 'floor purchased price (put),oil,average price per barrel', 'floor sold price (put),oil,average price per barrel']
# Split  0 pure columns:
#  ['three way collars (mbbls/d),oil,', 'ceiling sold price (call),oil,average price per barrel', 'floor purchased price (put),oil,average price per barrel', 'floor sold price (put),oil,average price per barrel']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>three way collars (mbbls/d),oil,</th>
#       <th>ceiling sold price (call),oil,average price per barrel</th>
#       <th>floor purchased price (put),oil,average price per barrel</th>
#       <th>floor sold price (put),oil,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2016 Settlement</td>
#       <td>83</td>
#       <td>$63.82</td>
#       <td>$54.46</td>
#       <td>$42.77</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>three way collars (mbbls/d),oil,</th>
#       <th>ceiling sold price (call),oil,average price per barrel</th>
#       <th>floor purchased price (put),oil,average price per barrel</th>
#       <th>floor sold price (put),oil,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2016 Settlement</td>
#       <td>83</td>
#       <td>$63.82</td>
#       <td>$54.46</td>
#       <td>$42.77</td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  gas_split
# Split  1 columns:
#  [',,product_type,additional', 'fixed price contracts (thousand mmbtu/d),natural gas,average price per barrel', 'average price per mmbtu,natural gas,average price per barrel']
# Split  1 pure columns:
#  ['fixed price contracts (thousand mmbtu/d),natural gas,average price per barrel', 'average price per mmbtu,natural gas,average price per barrel']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,average price per barrel</th>
#       <th>average price per mmbtu,natural gas,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2016 Settlement</td>
#       <td>38</td>
#       <td>$2.53</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,average price per barrel</th>
#       <th>average price per mmbtu,natural gas,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2016 Settlement</td>
#       <td>38</td>
#       <td>$2.53</td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  ngl_split
# Split  2 columns:
#  [',,product_type,additional', 'fixed price contracts (mbbls/d),ngls,average price per barrel', 'average price per barrel,ngls,average price per barrel']
# Split  2 pure columns:
#  ['fixed price contracts (mbbls/d),ngls,average price per barrel', 'average price per barrel,ngls,average price per barrel']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>fixed price contracts (mbbls/d),ngls,average price per barrel</th>
#       <th>average price per barrel,ngls,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2016 Settlement</td>
#       <td>4</td>
#       <td>$13.07</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>fixed price contracts (mbbls/d),ngls,average price per barrel</th>
#       <th>average price per barrel,ngls,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2016 Settlement</td>
#       <td>4</td>
#       <td>$13.07</td>
#     </tr>
#   </tbody>
# </table>
# APC20170217
# Splitting on  oil_split
# Split  0 columns:
#  [',,product_type,additional', 'three way collars (mbbls/d),oil,', 'ceiling sold price (call),oil,average price per barrel', 'floor purchased price (put),oil,average price per barrel', 'floor sold price (put),oil,average price per barrel']
# Split  0 pure columns:
#  ['three way collars (mbbls/d),oil,', 'ceiling sold price (call),oil,average price per barrel', 'floor purchased price (put),oil,average price per barrel', 'floor sold price (put),oil,average price per barrel']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>three way collars (mbbls/d),oil,</th>
#       <th>ceiling sold price (call),oil,average price per barrel</th>
#       <th>floor purchased price (put),oil,average price per barrel</th>
#       <th>floor sold price (put),oil,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2017 Settlement</td>
#       <td>91</td>
#       <td>$59.80</td>
#       <td>$50.00</td>
#       <td>$40.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>,2018 Settlement</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>three way collars (mbbls/d),oil,</th>
#       <th>ceiling sold price (call),oil,average price per barrel</th>
#       <th>floor purchased price (put),oil,average price per barrel</th>
#       <th>floor sold price (put),oil,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2017 Settlement</td>
#       <td>91</td>
#       <td>$59.80</td>
#       <td>$50.00</td>
#       <td>$40.00</td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  gas_split
# Split  1 columns:
#  [',,product_type,additional', 'three way collars (thousand mmbtu/d),natural gas,average price per barrel', 'ceiling sold price (call),natural gas,average price per mmbtu', 'floor purchased price (put),natural gas,average price per mmbtu', 'floor sold price (put),natural gas,average price per mmbtu', 'fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu', 'average price per mmbtu,natural gas,average price per mmbtu']
# Split  1 pure columns:
#  ['three way collars (thousand mmbtu/d),natural gas,average price per barrel', 'ceiling sold price (call),natural gas,average price per mmbtu', 'floor purchased price (put),natural gas,average price per mmbtu', 'floor sold price (put),natural gas,average price per mmbtu', 'fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu', 'average price per mmbtu,natural gas,average price per mmbtu']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,average price per barrel</th>
#       <th>ceiling sold price (call),natural gas,average price per mmbtu</th>
#       <th>floor purchased price (put),natural gas,average price per mmbtu</th>
#       <th>floor sold price (put),natural gas,average price per mmbtu</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu</th>
#       <th>average price per mmbtu,natural gas,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2017 Settlement</td>
#       <td>682</td>
#       <td>$3.60</td>
#       <td>$2.75</td>
#       <td>$2.00</td>
#       <td>37</td>
#       <td>$3.23</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>,2018 Settlement</td>
#       <td>250</td>
#       <td>$3.54</td>
#       <td>$2.75</td>
#       <td>$2.00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,average price per barrel</th>
#       <th>ceiling sold price (call),natural gas,average price per mmbtu</th>
#       <th>floor purchased price (put),natural gas,average price per mmbtu</th>
#       <th>floor sold price (put),natural gas,average price per mmbtu</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu</th>
#       <th>average price per mmbtu,natural gas,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2017 Settlement</td>
#       <td>682</td>
#       <td>$3.60</td>
#       <td>$2.75</td>
#       <td>$2.00</td>
#       <td>37</td>
#       <td>$3.23</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>,2018 Settlement</td>
#       <td>250</td>
#       <td>$3.54</td>
#       <td>$2.75</td>
#       <td>$2.00</td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Splitting on  ngl_split
# Split  2 columns:
#  [',,product_type,additional', 'fixed price contracts (mbbls/d),ngls,average price per mmbtu', 'average price per barrel,ngls,average price per mmbtu']
# Split  2 pure columns:
#  ['fixed price contracts (mbbls/d),ngls,average price per mmbtu', 'average price per barrel,ngls,average price per mmbtu']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>fixed price contracts (mbbls/d),ngls,average price per mmbtu</th>
#       <th>average price per barrel,ngls,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2017 Settlement</td>
#       <td>2</td>
#       <td>$15.84</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>,2018 Settlement</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,,product_type,additional</th>
#       <th>fixed price contracts (mbbls/d),ngls,average price per mmbtu</th>
#       <th>average price per barrel,ngls,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2017 Settlement</td>
#       <td>2</td>
#       <td>$15.84</td>
#     </tr>
#   </tbody>
# </table>
# APC20040304
# APC20040304 Table: 0 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,natural gas,additional</th>
#       <th>three way collars (thousand mmbtu/d),</th>
#       <th>floor sold price,nymex price per mmbtu</th>
#       <th>floor purchased price,nymex price per mmbtu</th>
#       <th>ceiling sold price,nymex price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004,</td>
#       <td>319</td>
#       <td>$2.87</td>
#       <td>$3.94</td>
#       <td>$5.52</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005,</td>
#       <td>19</td>
#       <td>$2.20</td>
#       <td>$3.00</td>
#       <td>$4.83</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>price_3</th>
#       <th>price_3_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004</td>
#       <td>319</td>
#       <td>mmbtu/d</td>
#       <td>$2.87</td>
#       <td>floor sold</td>
#       <td>$3.94</td>
#       <td>floor purchased</td>
#       <td>$5.52</td>
#       <td>ceiling sold</td>
#       <td>three way collar</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005</td>
#       <td>19</td>
#       <td>mmbtu/d</td>
#       <td>$2.20</td>
#       <td>floor sold</td>
#       <td>$3.00</td>
#       <td>floor purchased</td>
#       <td>$4.83</td>
#       <td>ceiling sold</td>
#       <td>three way collar</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# APC20040304 ,table:0-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>price_3</th>
#       <th>price_3_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004</td>
#       <td>319</td>
#       <td>mmbtu/d</td>
#       <td>$2.87</td>
#       <td>floor sold</td>
#       <td>$3.94</td>
#       <td>floor purchased</td>
#       <td>$5.52</td>
#       <td>ceiling sold</td>
#       <td>three way collar</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005</td>
#       <td>19</td>
#       <td>mmbtu/d</td>
#       <td>$2.20</td>
#       <td>floor sold</td>
#       <td>$3.00</td>
#       <td>floor purchased</td>
#       <td>$4.83</td>
#       <td>ceiling sold</td>
#       <td>three way collar</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20040304 Table: 1 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,natural gas,additional</th>
#       <th>two way collars (thousand mmbtu/d),nymex price per mmbtu</th>
#       <th>floor purchased price,nymex price per mmbtu,</th>
#       <th>ceiling sold price,nymex price per mmbtu,</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004,</td>
#       <td>44</td>
#       <td>$4.29</td>
#       <td>$6.43</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005,</td>
#       <td>26</td>
#       <td>$3.76</td>
#       <td>$5.65</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004</td>
#       <td>44</td>
#       <td>mmbtu/d</td>
#       <td>$4.29</td>
#       <td>floor purchased</td>
#       <td>$6.43</td>
#       <td>ceiling sold</td>
#       <td>two way collar</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005</td>
#       <td>26</td>
#       <td>mmbtu/d</td>
#       <td>$3.76</td>
#       <td>floor purchased</td>
#       <td>$5.65</td>
#       <td>ceiling sold</td>
#       <td>two way collar</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# APC20040304 ,table:1-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004</td>
#       <td>44</td>
#       <td>mmbtu/d</td>
#       <td>$4.29</td>
#       <td>floor purchased</td>
#       <td>$6.43</td>
#       <td>ceiling sold</td>
#       <td>two way collar</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005</td>
#       <td>26</td>
#       <td>mmbtu/d</td>
#       <td>$3.76</td>
#       <td>floor purchased</td>
#       <td>$5.65</td>
#       <td>ceiling sold</td>
#       <td>two way collar</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20040304 Table: 2 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,natural gas,additional</th>
#       <th>fixed price (thousand mmbtu/d),nymex price per mmbtu</th>
#       <th>nymex price per mmbtu,nymex price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004,</td>
#       <td>259</td>
#       <td>$3.86</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005,</td>
#       <td>33</td>
#       <td>$3.46</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004</td>
#       <td>259</td>
#       <td>mmbtu/d</td>
#       <td>$3.86</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005</td>
#       <td>33</td>
#       <td>mmbtu/d</td>
#       <td>$3.46</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# APC20040304 ,table:2-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004</td>
#       <td>259</td>
#       <td>mmbtu/d</td>
#       <td>$3.86</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005</td>
#       <td>33</td>
#       <td>mmbtu/d</td>
#       <td>$3.46</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20040304 Table: 3 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,natural gas,additional</th>
#       <th>basis swaps (thousand mmbtu/d),nymex price per mmbtu</th>
#       <th>price per mmbtu,nymex price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004,</td>
#       <td>197</td>
#       <td>$(0.13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005,</td>
#       <td>53</td>
#       <td>$(0.22</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004</td>
#       <td>197</td>
#       <td>mmbtu/d</td>
#       <td>$(0.13</td>
#       <td>price per mmbtu</td>
#       <td>basis swap</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005</td>
#       <td>53</td>
#       <td>mmbtu/d</td>
#       <td>$(0.22</td>
#       <td>price per mmbtu</td>
#       <td>basis swap</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# APC20040304 ,table:3-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004</td>
#       <td>197</td>
#       <td>mmbtu/d</td>
#       <td>$(0.13</td>
#       <td>price per mmbtu</td>
#       <td>basis swap</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005</td>
#       <td>53</td>
#       <td>mmbtu/d</td>
#       <td>$(0.22</td>
#       <td>price per mmbtu</td>
#       <td>basis swap</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20040304 Table: 4 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>,crude oil,additional</th>
#       <th>three way collars (mbbls/d),</th>
#       <th>floor sold price,nymex price per barrel</th>
#       <th>floor purchased price,nymex price per barrel</th>
#       <th>ceiling sold price,nymex price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004,,</td>
#       <td>38.0</td>
#       <td>$20.13</td>
#       <td>$24.61</td>
#       <td>$30.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005,</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>price_3</th>
#       <th>price_3_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004</td>
#       <td>38.0</td>
#       <td>mbbls/d</td>
#       <td>$20.13</td>
#       <td>floor sold</td>
#       <td>$24.61</td>
#       <td>floor purchased</td>
#       <td>$30.0</td>
#       <td>ceiling sold</td>
#       <td>three way collar</td>
#       <td>oil</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2005</td>
#       <td></td>
#       <td>mbbls/d</td>
#       <td></td>
#       <td>floor sold</td>
#       <td></td>
#       <td>floor purchased</td>
#       <td></td>
#       <td>ceiling sold</td>
#       <td>@</td>
#       <td>oil</td>
#     </tr>
#   </tbody>
# </table>
# APC20040304 ,table:4-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>price_3</th>
#       <th>price_3_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2004</td>
#       <td>38.0</td>
#       <td>mbbls/d</td>
#       <td>$20.13</td>
#       <td>floor sold</td>
#       <td>$24.61</td>
# ...
#     <tr>
#       <th>1</th>
#       <td>,2015 Settlement</td>
#       <td>170</td>
#       <td>$4.17</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2015</td>
#       <td>170</td>
#       <td>mmbtu/d</td>
#       <td>$4.17</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# APC20150220 ,table:1-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2015</td>
#       <td>170</td>
#       <td>mmbtu/d</td>
#       <td>$4.17</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20160217
# APC20160217 Table: 0 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_typeadditional</th>
#       <th>three way collars (mbbls/d),oil,</th>
#       <th>ceiling sold price (call),oil,average price per barrel</th>
#       <th>floor purchased price (put),oil,average price per barrel</th>
#       <th>floor sold price (put),oil,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2016 Settlement</td>
#       <td>83</td>
#       <td>$63.82</td>
#       <td>$54.46</td>
#       <td>$42.77</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>price_3</th>
#       <th>price_3_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2016</td>
#       <td>83</td>
#       <td>mbbls/d</td>
#       <td>$63.82</td>
#       <td>ceiling sold</td>
#       <td>$54.46</td>
#       <td>floor purchased</td>
#       <td>$42.77</td>
#       <td>floor sold</td>
#       <td>three way collar</td>
#       <td>oil</td>
#     </tr>
#   </tbody>
# </table>
# APC20160217 ,table:0-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>price_3</th>
#       <th>price_3_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2016</td>
#       <td>83</td>
#       <td>mbbls/d</td>
#       <td>$63.82</td>
#       <td>ceiling sold</td>
#       <td>$54.46</td>
#       <td>floor purchased</td>
#       <td>$42.77</td>
#       <td>floor sold</td>
#       <td>three way collar</td>
#       <td>oil</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20160217 Table: 1 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_typeadditional</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,average price per barrel</th>
#       <th>average price per mmbtu,natural gas,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2016 Settlement</td>
#       <td>38</td>
#       <td>$2.53</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2016</td>
#       <td>38</td>
#       <td>mmbtu/d</td>
#       <td>$2.53</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# APC20160217 ,table:1-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2016</td>
#       <td>38</td>
#       <td>mmbtu/d</td>
#       <td>$2.53</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20160217 Table: 2 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_typeadditional</th>
#       <th>fixed price contracts (mbbls/d),ngls,average price per barrel</th>
#       <th>average price per barrel,ngls,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2016 Settlement</td>
#       <td>4</td>
#       <td>$13.07</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2016</td>
#       <td>4</td>
#       <td>mbbls/d</td>
#       <td>$13.07</td>
#       <td>price per barrel</td>
#       <td>fixed price</td>
#       <td>oil</td>
#     </tr>
#   </tbody>
# </table>
# APC20160217 ,table:2-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2016</td>
#       <td>4</td>
#       <td>mbbls/d</td>
#       <td>$13.07</td>
#       <td>price per barrel</td>
#       <td>fixed price</td>
#       <td>oil</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20170217
# APC20170217 Table: 0 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_typeadditional</th>
#       <th>three way collars (mbbls/d),oil,</th>
#       <th>ceiling sold price (call),oil,average price per barrel</th>
#       <th>floor purchased price (put),oil,average price per barrel</th>
#       <th>floor sold price (put),oil,average price per barrel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2017 Settlement</td>
#       <td>91</td>
#       <td>$59.80</td>
#       <td>$50.00</td>
#       <td>$40.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>price_3</th>
#       <th>price_3_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2017</td>
#       <td>91</td>
#       <td>mbbls/d</td>
#       <td>$59.80</td>
#       <td>ceiling sold</td>
#       <td>$50.00</td>
#       <td>floor purchased</td>
#       <td>$40.00</td>
#       <td>floor sold</td>
#       <td>three way collar</td>
#       <td>oil</td>
#     </tr>
#   </tbody>
# </table>
# APC20170217 ,table:0-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>price_3</th>
#       <th>price_3_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2017</td>
#       <td>91</td>
#       <td>mbbls/d</td>
#       <td>$59.80</td>
#       <td>ceiling sold</td>
#       <td>$50.00</td>
#       <td>floor purchased</td>
#       <td>$40.00</td>
#       <td>floor sold</td>
#       <td>three way collar</td>
#       <td>oil</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20170217 Table: 1 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_typeadditional</th>
#       <th>three way collars (thousand mmbtu/d),natural gas,average price per barrel</th>
#       <th>ceiling sold price (call),natural gas,average price per mmbtu</th>
#       <th>floor purchased price (put),natural gas,average price per mmbtu</th>
#       <th>floor sold price (put),natural gas,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2017 Settlement</td>
#       <td>682</td>
#       <td>$3.60</td>
#       <td>$2.75</td>
#       <td>$2.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>,2018 Settlement</td>
#       <td>250</td>
#       <td>$3.54</td>
#       <td>$2.75</td>
#       <td>$2.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>price_3</th>
#       <th>price_3_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2017</td>
#       <td>682</td>
#       <td>mmbtu/d</td>
#       <td>$3.60</td>
#       <td>ceiling sold</td>
#       <td>$2.75</td>
#       <td>floor purchased</td>
#       <td>$2.00</td>
#       <td>floor sold</td>
#       <td>three way collar</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018</td>
#       <td>250</td>
#       <td>mmbtu/d</td>
#       <td>$3.54</td>
#       <td>ceiling sold</td>
#       <td>$2.75</td>
#       <td>floor purchased</td>
#       <td>$2.00</td>
#       <td>floor sold</td>
#       <td>three way collar</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# APC20170217 ,table:1-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>price_2</th>
#       <th>price_2_type</th>
#       <th>price_3</th>
#       <th>price_3_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2017</td>
#       <td>682</td>
#       <td>mmbtu/d</td>
#       <td>$3.60</td>
#       <td>ceiling sold</td>
#       <td>$2.75</td>
#       <td>floor purchased</td>
#       <td>$2.00</td>
#       <td>floor sold</td>
#       <td>three way collar</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018</td>
#       <td>250</td>
#       <td>mmbtu/d</td>
#       <td>$3.54</td>
#       <td>ceiling sold</td>
#       <td>$2.75</td>
#       <td>floor purchased</td>
#       <td>$2.00</td>
#       <td>floor sold</td>
#       <td>three way collar</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20170217 Table: 2 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_typeadditional</th>
#       <th>fixed price contracts (thousand mmbtu/d),natural gas,average price per mmbtu</th>
#       <th>average price per mmbtu,natural gas,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2017 Settlement</td>
#       <td>37</td>
#       <td>$3.23</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>,2018 Settlement</td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2017</td>
#       <td>37</td>
#       <td>mmbtu/d</td>
#       <td>$3.23</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018</td>
#       <td></td>
#       <td>mmbtu/d</td>
#       <td></td>
#       <td>price per mmbtu</td>
#       <td>@</td>
#       <td>@</td>
#     </tr>
#   </tbody>
# </table>
# APC20170217 ,table:2-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2017</td>
#       <td>37</td>
#       <td>mmbtu/d</td>
#       <td>$3.23</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# APC20170217 Table: 3 ---------- Before Sam function
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_typeadditional</th>
#       <th>fixed price contracts (mbbls/d),ngls,average price per mmbtu</th>
#       <th>average price per barrel,ngls,average price per mmbtu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>,2017 Settlement</td>
#       <td>2</td>
#       <td>$15.84</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2017</td>
#       <td>2</td>
#       <td>mbbls/d</td>
#       <td>$15.84</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# APC20170217 ,table:3-----After Sam functions----
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>maturity</th>
#       <th>vol_1</th>
#       <th>vol_1_type</th>
#       <th>price_1</th>
#       <th>price_1_type</th>
#       <th>instrument_type</th>
#       <th>product_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>2017</td>
#       <td>2</td>
#       <td>mbbls/d</td>
#       <td>$15.84</td>
#       <td>price per mmbtu</td>
#       <td>fixed price</td>
#       <td>natural gas</td>
#     </tr>
#   </tbody>
# </table>
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 14
# 2 14
# 3 14
# 4 14
# 5 14
# 14
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# (97, 15)
# Check the red_flag column for missing values at

# %%
lst = ['a']
type(lst[~0])
# Out:
# str

# %%
lst1 = [1, 2, 1, 0, 0]
lst2 = [0, 1, 1, 0, 2]

lst1 = [True if x == 0 else False for x in lst1]
lst2 = [True if x == 0 else False for x in lst2]

lst3 = [x & y for x,y in zip(lst1, lst2)]

print(lst1, '\n', lst2, '\n', lst3)
# Out:
# [False, False, False, True, True]
#  [True, False, False, True, False]
#  [False, False, False, True, False]

# %%
(big_df['red_flag'] == 1) & (big_df['red_flag'] != 1)
# Out:
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 5     False
# 6     False
# 7     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
#       ...
# 8     False
# 9     False
# 10    False
# 11    False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 2     False
# 3     False
# 4     False
# 2     False
# 3     False
# 2     False
# 3     False
# 4     False
# 5     False
# 2     False
# 3     False
# 4     False
# 2     False
# 3     False
# 2     False
# 2     False
# 3     False
# 2     False
# 2     False
# 3     False
# 2     False
# Name: red_flag, Length: 112, dtype: bool

# %%
not(True)
# Out:
# False
