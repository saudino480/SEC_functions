# %%
import numpy as np
import pandas as pd

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
# pip install fredapi

# ! pip install yfinance
# import yfinance as yf

# %%
from fredapi import Fred
fred = Fred(api_key = '2d063b4e6530724ac4a200b65467a14b')

# %% [markdown]
# ### Macro Economics Data from FRED ST.Louis - Quarterly

# %%
# Quarterly RGDP chained 2012 no seasonal adjustment (2003-2017)
RGDP_Q = fred.get_series('GDPC1', observation_start='1/1/2003', 
                                  observation_end='10/1/2017')   # <- can adjust

# CPI Quarterly
# Quarterly Consumer Price Index: Energy for the United States (2003 - 2017)
ENGCPI_Q = fred.get_series('USACPIENGQINMEI', observation_start='1/1/2003',
                                            observation_end='12/1/2017')

# Expenditure
# Quarterly Personal Consumption Expenditures for Nonedurable goods(Gasoline&other Energy goods)
ENGPCE_Q = fred.get_series('DGOERC1Q027SBEA', observation_start='1/1/2003',
                                             observation_end='10/1/2017')


# POILWTIUSDM
# Quarterly Global price of WTI Crude
Global_Crude_Q = fred.get_series('POILWTIUSDM', observation_start='1/1/2003',
                                            observation_end='12/1/2017', frequency = 'q')



RGDP_Q = pd.DataFrame(RGDP_Q, columns = ['quarterly_rgdp'])
ENGCPI_Q = pd.DataFrame(ENGCPI_Q, columns=['CPI for Energy'])
ENGPCE_Q = pd.DataFrame(ENGPCE_Q, columns=['energy_cpi_q'])
Global_Crude_Q = pd.DataFrame(Global_Crude, columns=['Global Price U.S. Dollars per Barrel'])

# %%
Global_Crude_Q.head()
# Out:
#             Global Price U.S. Dollars per Barrel
# 2003-01-01                             34.027811
# 2003-04-01                             29.080000
# 2003-07-01                             30.250446
# 2003-10-01                             31.174812
# 2004-01-01                             35.192298

# %%
# GDP
# Annual RGDP chained 2012 no seasonal adjustment (2003-2017)
RGDP_A = fred.get_series('GDPCA', observation_start='1/1/2003',
                                  observation_end='1/1/2017')     # <- can adjust


# Inflation 
# Monthly 10-year Breakeven Inflation Rate(Monthly)
BEI_M = fred.get_series('T10YIEM', observation_start='1/1/2003',
                                    observation_end='12/1/2017')


# CPI
# Monthly Energy CPI for US (2003 2017)
ENGCPI_M = fred.get_series('USACPIENGMINMEI', observation_start='1/1/2003',
                                            observation_end='12/1/2017')





# Money Supply M2
# Monthly Money Supply M2 for US (2003 - 2019)
M2 = fred.get_series('M2SL', observation_start='1/1/2003',
                                            observation_end='12/1/2017')

# ACDGNO 
#Monthly Value of Manufacturers' New Orders for Consumer Goods: Consumer Durable Goods Industries (ACDGNO)

ACDGNO = fred.get_series('ACDGNO', observation_start='1/1/2003',
                                            observation_end='12/1/2017')

# POILWTIUSDM
# Monthly Global price of WTI Crude
Global_Crude = fred.get_series('POILWTIUSDM', observation_start='1/1/2003',
                                            observation_end='12/1/2017')

# NATURALGASD11
# Monthly Natural Gas Consumption

gas_consumption = fred.get_series('NATURALGASD11', observation_start='1/1/2003',
                                            observation_end='12/1/2017')


RGDP_A = pd.DataFrame(RGDP_A, columns= ['annual_rgdp']) 
BEI_M = pd.DataFrame(BEI_M, columns=['breakeven_inflation'])
ENGCPI_M = pd.DataFrame(ENGCPI_M, columns=['CPI for Energy'])

M2_M = pd.DataFrame(M2, columns=['M2SL in Billions of Dollars'])
ACDGNO_M = pd.DataFrame(ACDGNO, columns=['ACDGNO in Million of Dollars'])
Global_Crude_M = pd.DataFrame(Global_Crude, columns=['Global Price U.S. Dollars per Barrel'])
Gas_Cnsmp_M = pd.DataFrame(gas_consumption, columns=['NG Consumption Billion Cubic Feet'])

# %%
RGDP_A
RGDP_Q
BEI_M
ENGCPI_M
ENGPCE_Q

# %%
crude_gas_monthly = pd.read_csv('crude_gas_monthly.csv')
crude_gas_monthly = pd.DataFrame(crude_gas_monthly)
crude_gas_monthly.set_index('Date', inplace = True)

# %%
# Concatenating the dataframes
macro_data_monthly = pd.concat([BEI_M, ENGCPI_M, M2_M, ACDGNO_M, crude_gas_monthly, 
                                Global_Crude_M, Gas_Cnsmp_M], axis = 'columns')

# %%
crude_gas_daily = pd.read_csv('crude_gas_daily.csv')
crude_gas_daily
# Out:
#             Date  \
# 0     2003-01-02
# 1     2003-01-03
# 2     2003-01-06
# 3     2003-01-07
# 4     2003-01-08
# 5     2003-01-09
# 6     2003-01-10
# 7     2003-01-13
# 8     2003-01-14
# 9     2003-01-15
# 10    2003-01-16
# 11    2003-01-17
# 12    2003-01-21
# 13    2003-01-22
# 14    2003-01-23
# 15    2003-01-24
# 16    2003-01-27
# 17    2003-01-28
# 18    2003-01-29
# 19    2003-01-30
# 20    2003-01-31
# 21    2003-02-03
# 22    2003-02-04
# 23    2003-02-05
# 24    2003-02-06
# 25    2003-02-07
# 26    2003-02-10
# 27    2003-02-11
# 28    2003-02-12
# 29    2003-02-13
# ...          ...
# 3714  2017-10-18
# 3715  2017-10-19
# 3716  2017-10-20
# 3717  2017-10-23
# 3718  2017-10-24
# 3719  2017-10-25
# 3720  2017-10-26
# 3721  2017-10-27
# 3722  2017-10-30
# 3723  2017-10-31
# 3724  2017-11-01
# 3725  2017-11-02
# 3726  2017-11-03
# 3727  2017-11-06
# 3728  2017-11-07
# 3729  2017-11-08
# 3730  2017-11-09
# 3731  2017-11-13
# 3732  2017-11-14
# 3733  2017-11-15
# ...

# %%
macro_data_monthly
# Out:
#             breakeven_inflation  CPI for Energy  M2SL in Billions of Dollars  \
# 2003-01-01                 1.76       62.840385                       5793.0
# 2003-02-01                 1.91       66.734025                       5829.2
# 2003-03-01                 1.87       70.282659                       5849.9
# 2003-04-01                 1.78       68.064763                       5887.1
# 2003-05-01                 1.66       66.044013                       5947.3
# 2003-06-01                 1.61       67.276177                       5984.0
# 2003-07-01                 1.87       67.424037                       6030.6
# 2003-08-01                 2.13       69.296927                       6088.7
# 2003-09-01                 2.08       71.268390                       6060.8
# 2003-10-01                 2.21       67.473324                       6051.5
# 2003-11-01                 2.34       65.600434                       6056.6
# ...

# %%
ticker = ['^GSPC']
hist_ticker = yf.download(ticker, '2003-01-01','2017-12-01', interval = '3mo')
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
production_qtr = pd.read_csv('./Time_series_data/production_qtr.csv')
production_qtr
# Out:
#      exchange  year                      comname ticker  TOTAL_PRODUCTION  \
# 0          US  2019      Anadarko Petroleum Corp    APC        743.500000
# 1          US  2019      Anadarko Petroleum Corp    APC        714.833333
# 2          US  2018      Anadarko Petroleum Corp    APC        701.333333
# 3          US  2018      Anadarko Petroleum Corp    APC        681.500000
# 4          US  2018      Anadarko Petroleum Corp    APC        636.833333
# 5          US  2018      Anadarko Petroleum Corp    APC               NaN
# 6          US  2017      Anadarko Petroleum Corp    APC        637.333333
# 7          US  2017      Anadarko Petroleum Corp    APC        626.000000
# 8          US  2017      Anadarko Petroleum Corp    APC        631.333333
# 9          US  2017      Anadarko Petroleum Corp    APC        794.833333
# 10         US  2016      Anadarko Petroleum Corp    APC        773.500000
# 11         US  2016      Anadarko Petroleum Corp    APC        782.608696
# ...

# %%
processed_file = pd.read_csv('./Time_series_data/output_after_sam.csv')
processed_file
# Out:
#       AHC20060309                              Unnamed: 1  \
# 0         table:0                                dattime1
# 1               5                                    2006
# 2               6                                    2007
# 3               7                                    2008
# 4               8                                    2009
# 5               9                                    2010
# 6              10                                    2011
# 7              11                                    2012
# 8     APA20060314                                     NaN
# 9         table:0                                dattime1
# 10              5                                    2006
# 11              6                                     NaN
# 12              7                                     NaN
# 13              8                                     NaN
# 14              9                                     NaN
# ...
